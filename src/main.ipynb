# %%
import modules.prepareData as prepareData
from importlib import reload
import pandas as pd
reload(prepareData)

# race_id_list = ["2021010101{}".format(str(i).zfill(2)) for i in range(1,13)]
# html_path_list = prepareData.getHTMLRace(race_id_list)

horse_id_list = pd.read_pickle("/workspace/data/raw/results/results_sample.pickle")["horse_id"].unique()

# %%
html_path_list_horse = prepareData.getHTMLHorse(horse_id_list)
# Out:
#   0%|          | 0/155 [00:00<?, ?it/s]
# horse_id 2018105875 skipped
# horse_id 2018105258 skipped
# horse_id 2018101134 skipped
# horse_id 2018102791 skipped
# horse_id 2018101539 skipped
# horse_id 2018100570 skipped
# horse_id 2018102192 skipped
# horse_id 2018102626 skipped
# horse_id 2018103582 skipped
# horse_id 2018101518 skipped
# horse_id 2018106100 skipped
# horse_id 2018101447 skipped
# horse_id 2018109106 skipped
# horse_id 2018106896 skipped
# horse_id 2018104780 skipped
# horse_id 2018100737 skipped
# horse_id 2018105205 skipped
# horse_id 2018100974 skipped
# horse_id 2018104870 skipped
# horse_id 2018106453 skipped
# horse_id 2018100926 skipped
# horse_id 2018102052 skipped
# horse_id 2018103196 skipped
# horse_id 2018101898 skipped
# horse_id 2018102542 skipped
# horse_id 2018103594 skipped
# horse_id 2018106609 skipped
# horse_id 2018100435 skipped
# horse_id 2018105770 skipped
# horse_id 2018100706 skipped
# horse_id 2018100403 skipped
# ...

# %%
import modules.prepareData as prepareData
from importlib import reload
reload(prepareData)

prepareData.getRawDataHorseResults(html_path_list_horse)
# Out:
#            日付    開催 天 気   R          レース名  映 像  頭 数  枠 番  馬 番  オ ッ ズ  ...  \
# 0  2022/10/10  4阪神3   曇  12     3歳以上2勝クラス  NaN   15    8   14   26.4  ...
# 1  2022/09/10  4中山1   晴  10   汐留特別(2勝クラス)  NaN   16    7   13   36.4  ...
# 2  2022/01/16  1小倉2   曇  10   小郡特別(2勝クラス)  NaN   12    7   10    3.5  ...
# 3  2021/12/26  6阪神8   曇  12  猪名川特別(2勝クラス)  NaN   15    2    2    8.2  ...
# 4  2021/10/30  4阪神7   晴   8     3歳以上2勝クラス  NaN   11    2    2    5.8  ...
# 5  2021/10/09  4東京1   曇  12     3歳以上2勝クラス  NaN   13    5    7   13.8  ...
# 6  2021/07/04  1函館2   曇   9     3歳以上1勝クラス  NaN   16    3    5    7.3  ...
# 7  2021/06/12  1札幌1  小雨   1         3歳未勝利  NaN   16    5    9   13.5  ...
# 8  2021/04/10  1新潟1   晴   5         3歳未勝利  NaN   16    8   16   13.7  ...
#
#     着差  ﾀｲﾑ 指数     通過        ペース    上り       馬体重 厩舎 ｺﾒﾝﾄ  備考    勝ち馬 (2着馬)  \
# 0  2.3      **   9-12  34.0-36.9  38.1   482(+2)     NaN NaN       ディアノイア
# 1  1.3      **  11-12  32.6-35.0  35.1   480(+6)     NaN NaN      ブレスレスリー
# ...
